# %%
import pandas as pd
import copy
import os
import warnings
from datetime import datetime

pd.set_option('display.max_columns', None)
warnings.simplefilter("ignore", FutureWarning)

# %%
CLAIMS = {
    'SVC' : {
        'SVC01' : {
            '01' : 'HC',
            '02' : '',
            # '03' : '',
            # '04' : '',
            # '05' : '',
            # '06' : '',
            # '07' : '',
            # '08' : '',
        },
        'SVC02' : '',
        'SVC03' : '',
        'SVC04' : '',
        'SVC05' : '',
        'SVC06' : '',
        #  {
        #     '01' : '',
        #     '02' : '',
        #     '03' : '',
        #     '04' : '',
        #     '05' : '',
        #     '06' : '',
        #     '07' : '',
        #     '08' : '',
        # },
        'SVC07' : '',
    },

    'DTM' : {
        'DTM01' : '472',
        'DTM02' : '',
    },

    # 'CAS' : {
    #     'CAS01' : 'CO',
    #     'CAS02' : '45',
    #     'CAS03' : '',
    #     # 'CAS04' : '',
    #     # 'CAS05' : '',
    #     # 'CAS06' : '',
    #     # 'CAS07' : '',
    #     # 'CAS08' : '',
    #     # 'CAS09' : '',
    #     # 'CAS10' : '',
    #     # 'CAS11' : '',
    #     # 'CAS12' : '',
    #     # 'CAS13' : '',
    #     # 'CAS14' : '',
    #     # 'CAS15' : '',
    #     # 'CAS16' : '',
    #     # 'CAS17' : '',
    #     # 'CAS18' : '',
    #     # 'CAS19' : '',
    # },

    'REF' : {
        # 'SERVICE IDENTIFICATION' : {
        #     'REF01' : '',
        #     'REF02' : '',
        #     'REF03' : '',
        # },

        'LINE ITEM CONTROL NUMBER' : {
            'REF01' : '6R',
            'REF02' : '',
            'REF03' : '',
        },

        # 'RENDERING PROVIDER' : {
        #     'REF01' : 'HPI',
        #     'REF02' : '',
        #     'REF03' : '',
        # },

        # 'HEALTHCARE POLICY' : {
        #     'REF01' : '',
        #     'REF02' : '',
        #     'REF03' : '',
        # },
    },

    'AMT' : {
        'AMT01' : 'B6',
        'AMT02' : '',
    },

    # 'QTY' : '',

    'LQ' : {
        'LQ01' : 'HE',
        'LQ02' : 'N83',
    },
}
    
HEADERS = {
    'CLP' : {
        'CLP01' : '',
        'CLP02' : '2',
        'CLP03' : '',
        'CLP04' : '',
        'CLP05' : '',
        'CLP06' : '',
        'CLP07' : '',
        'CLP08' : '',
        'CLP09' : '',
        'CLP10' : '',
        'CLP11' : '',
        'CLP12' : '',
        'CLP13' : '',
        'CLP14' : '',
    },

    'CAS' : {
        'CAS01' : 'CO',
        'CAS02' : '132',
        'CAS03' : '',
    #     'CAS04' : '',
    #     'CAS05' : '',
    #     'CAS06' : '',
    #     'CAS07' : '',
    #     'CAS08' : '',
    #     'CAS09' : '',
    #     'CAS10' : '',
    #     'CAS11' : '',
    #     'CAS12' : '',
    #     'CAS13' : '',
    #     'CAS14' : '',
    #     'CAS15' : '',
    #     'CAS16' : '',
    #     'CAS17' : '',
    #     'CAS18' : '',
    #     'CAS19' : '',
    },

    'NM1' : {
        'PATIENT' : {
            'NM101' : 'QC',
            'NM102' : '1',
            'NM103' : '', 
            'NM104' : '', 
            'NM105' : '',
            'NM106' : '',
            'NM107' : '',
            'NM108' : 'MI',
            'NM109' : '',
        },

        'INSURED' : {
            'NM101' : 'IL',
            'NM102' : '1',
            'NM103' : '', 
            'NM104' : '', 
            'NM105' : '',
            'NM106' : '',
            'NM107' : '',
            'NM108' : 'MI',
            'NM109' : '',
        },

        # 'CORRECTED PATIENT' : {
        #     'NM101' : '',
        #     'NM102' : '',
        #     'NM103' : '',
        #     'NM104' : '',
        #     'NM105' : '',
        #     'NM106' : '',
        #     'NM107' : '',
        #     'NM108' : '',
        #     'NM109' : '',
        #     'NM110' : '',
        # },

        'SERVICE PROVIDER' : {
            'NM101' : '82',
            'NM102' : '',
            'NM103' : '',
            'NM104' : '',
            'NM105' : '',
            'NM106' : '',
            'NM107' : '',
            'NM108' : '',
            'NM109' : '',
        },

        # 'CROSSOVER CARRIER' : {
        #     'NM101' : '',
        #     'NM102' : '',
        #     'NM103' : '',
        #     'NM104' : '',
        #     'NM105' : '',
        #     'NM106' : '',
        #     'NM107' : '',
        #     'NM108' : '',
        #     'NM109' : '',
        #     'NM110' : '',
        # },

        # 'CORRECTED PAYER' : {
        #     'NM101' : '',
        #     'NM102' : '',
        #     'NM103' : '',
        #     'NM104' : '',
        #     'NM105' : '',
        #     'NM106' : '',
        #     'NM107' : '',
        #     'NM108' : '',
        #     'NM109' : '',
        #     'NM110' : '',
        # },

        # 'SUBSCRIBER' : '',
    },

    # 'MIA' : {
    #     'MIA01' : '',
    #     'MIA02' : '',
    #     'MIA03' : '',
    #     'MIA04' : '',
    #     'MIA05' : '',
    #     'MIA06' : '',
    #     'MIA07' : '',
    #     'MIA08' : '',
    #     'MIA09' : '',
    #     'MIA10' : '',
    #     'MIA11' : '',
    #     'MIA12' : '',
    #     'MIA13' : '',
    #     'MIA14' : '',
    #     'MIA15' : '',
    #     'MIA16' : '',
    #     'MIA17' : '',
    #     'MIA18' : '',
    #     'MIA19' : '',
    #     'MIA20' : '',
    #     'MIA21' : '',
    #     'MIA22' : '',
    #     'MIA23' : '',
    #     'MIA24' : '',
    # },

    # 'MOA' : {
    #     'MOA01' : '',
    #     'MOA02' : '',
    #     'MOA03' : '',
    #     'MOA04' : '',
    #     'MOA05' : '',
    #     'MOA06' : '',
    #     'MOA07' : '',
    #     'MOA08' : '',
    #     'MOA09' : '',
    # },

    'REF' : {
        'CLAIM RELATED' : {
            'REF01' : 'EA',
            'REF02' : '',
        },

        # 'RENDERING PROVIDER' : '',
    },

    'DTM' : {
        'STATEMENT FROM TO' : {
            'DTM01' : '232',
            'DTM02' : '',
        },

        'COVERAGE EXPIRATION' : {
            'DTM01' : '233',
            'DTM02' : '',
        },

        'CLAIM RECEIVED' : {
            'DTM01' : '050',
            'DTM02' : '',
        },
    },

    # 'PER' : {
    #     'PER01' : 'CX',
    #     'PER02' : 'Jonathan Moore',
    #     'PER03' : 'TE',
    #     'PER04' : '7162475282',
    #     'PER05' : '',
    #     'PER06' : '',
    #     'PER07' : '',
    #     'PER08' : '',
    #     'PER09' : '',
    # },

    # 'AMT' : {
    #     'AMT01' : 'AU',
    #     'AMT02' : '',
    # },

    # 'QTY' : {
    #     'QTY01' : '',
    #     'QTY02' : '',
    #     'QTY03' : '',
    # },

    'CLAIMS' : [],
}

LX = {
    'LX' : '',

    # 'TS3' : {
    #     'TS301' : '',
    #     'TS302' : '',
    #     'TS303' : '',
    #     'TS304' : '',
    #     'TS305' : '',
    #     'TS306' : '',
    #     'TS307' : '',
    #     'TS308' : '',
    #     'TS309' : '',
    #     'TS310' : '',
    #     'TS311' : '',
    #     'TS312' : '',
    #     'TS313' : '',
    #     'TS314' : '',
    #     'TS315' : '',
    #     'TS316' : '',
    #     'TS317' : '',
    #     'TS318' : '',
    #     'TS319' : '',
    #     'TS320' : '',
    #     'TS321' : '',
    #     'TS322' : '',
    #     'TS323' : '',
    #     'TS324' : '',
    # },

    # 'TS2' : {
    #     'TS201' : '',
    #     'TS202' : '',
    #     'TS203' : '',
    #     'TS204' : '',
    #     'TS205' : '',
    #     'TS206' : '',
    #     'TS207' : '',
    #     'TS208' : '',
    #     'TS209' : '',
    #     'TS210' : '',
    #     'TS211' : '',
    #     'TS212' : '',
    #     'TS213' : '',
    #     'TS214' : '',
    #     'TS215' : '',
    #     'TS216' : '',
    #     'TS217' : '',
    #     'TS218' : '',
    #     'TS219' : '',
    # },

    'HEADERS' : [],
}

DATA_835 = {
    'ISA' : {
        'ISA01' : '00',
        'ISA02' : '          ',
        'ISA03' : '00',
        'ISA04' : '          ',
        'ISA05' : 'ZZ',
        'ISA06' : '881873509',
        'ISA07' : '29',
        'ISA08' : 'OPTUM',
        'ISA09' : '',
        'ISA10' : '',
        'ISA11' : '^',
        'ISA12' : '00501',
        'ISA13' : '000092960',
        'ISA14' : '0',
        'ISA15' : 'P',
        'ISA16' : ':',
    },

    'GS' : {
        'GS01' : 'HP',
        'GS02' : '881873509', 
        'GS03' : 'OPTUM', 
        'GS04' : '',
        'GS05' : '',
        'GS06' : '92960',
        'GS07' : 'X',
        'GS08' : '005010X221A1',
    },

    'ST' : {
        'ST01' : '835',
        'ST02' : '0001',
        'ST03' : ''
    },

    'BPR' : {
        'BPR01' : 'I',
        'BPR02' : '',
        'BPR03' : 'C',
        'BPR04' : 'ACH',
        'BPR05' : 'CCP',
        'BPR06' : '01',
        'BPR07' : '2000046',
        'BPR08' : 'DA',
        'BPR09' : '9872632824',
        'BPR10' : '881873509',
        'BPR11' : '',
        'BPR12' : '01',
        'BPR13' : '',
        'BPR14' : 'DA',
        'BPR15' : '',
        'BPR16' : '',
        'BPR17' : '',
    },

    'TRN' : {
        'TRN01' : '1',
        'TRN02' : '',
        'TRN03' : '',
        'TRN04' : '',
    },

    'CUR' : '',

    'REF' : {
        'REFERENCE' : {
            'REF01' : 'EV',
            'REF02' : '99073',
            'REF03' : '',
        },

        'VERSION' : {
            'REF01' : '',
            'REF02' : '',
            'REF03' : '',
        },
    },

    'DTM' : {
        'DTM01' : '405',
        'DTM02' : '',
        'DTM03' : '',
    },

    'PAYER' : {
        'N1' : {
            'N101' : 'PR',
            'N102' : 'CINQCARE ACO REACH',
            'N103' : 'XV',
            'N104' : '881873509',
            'N105' : '',
        },

        'N3' : {
            'N301' : '2300 N Street NW Suite 200',
            'N302' : '',
        },

        'N4' : {
            'N401' : 'Washington',
            'N402' : 'DC',
            'N403' : '20037',
            'N404' : 'US',
            'N405' : '',
            'N406' : '',
            'N407' : '',
        },

        'REF' : {
            'REF01' : '2U',
            'REF02' : '06001',
        },

        'PER' : {
            'PAYER BUSINESS' : {
                'PER01' : 'CX',
                'PER02' : 'Jonathan Moore',
                'PER03' : 'TE',
                'PER04' : '7162475282',
                'PER05' : '',
                'PER06' : '',
                'PER07' : '',
                'PER08' : '',
                'PER09' : '',
            },

            'PAYER TECHNICAL' : {
                'PER01' : 'BL',
                'PER02' : 'Jonathan Moore',
                'PER03' : 'TE',
                'PER04' : '7162475282',
                'PER05' : '',
                'PER06' : '',
                'PER07' : '',
                'PER08' : '',
                'PER09' : '',
            },

            'PAYER WEB' : {
                'PER01' : 'IC',
                'PER02' : 'CINQCARE',
                'PER03' : 'UR',
                'PER04' : 'WWW.CINQ.CARE',
                'PER05' : '',
            },
        },
    },

    'PAYEE' : {
        'N1' : {
            'N101' : 'PE',
            'N102' : '',
            'N103' : 'XX',
            'N104' : '',
            'N105' : '',
            'N106' : '',
            'N107' : '',
        },

        'N3' : {
            'N301' : '',
            'N302' : '',
        },

        'N4' : {
            'N401' : '',
            'N402' : '',
            'N403' : '',
            'N404' : 'US',
            'N405' : '',
            'N406' : '',
            'N407' : '',
        },

        'REF' : {
            'REF01' : 'TJ',
            'REF02' : '',
        },

        # 'RDM' : {
        #     'RDM01' : '',
        #     'RDM02' : '',
        #     'RDM03' : '',
        #     'RDM04' : '',
        # },
    },

    'DATA' : [],

    # 'PLB' : {
    #     'PLB01' : '',
    #     'PLB02' : '',
    #     'PLB03' : {
    #         '01' : '',
    #         '02' : '',
    #     },
    #     'PLB04' : '',
    #     'PLB05' : {
    #         '01' : '',
    #         '02' : '',
    #     },
    #     'PLB06' : '',
    #     'PLB07' : {
    #         '01' : '',
    #         '02' : '',
    #     },
    #     'PLB08' : '',
    #     'PLB09' : {
    #         '01' : '',
    #         '02' : '',
    #     },
    #     'PLB10' : '',
    #     'PLB11' : {
    #         '01' : '',
    #         '02' : '',
    #     },
    #     'PLB12' : '',
    #     'PLB13' : {
    #         '01' : '',
    #         '02' : '',
    #     },
    #     'PLB14' : '',
    # },

    'SE' : {
        'SE01' : '',
        'SE02' : '',
    },

    'GE' : {
        'GE01' : '1',
        'GE02' : '',
    },

    'IEA' : {
        'IEA01' : '1',
        'IEA02' : '',
    },
}
